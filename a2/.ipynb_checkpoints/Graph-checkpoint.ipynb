# %%
import matplotlib.pyplot as plt
import numpy
# %matplotlib inline

# %%
Avg_16 = [1400,14748.3870968, 4300, 700, 151.523809524, 38.45]
Avg_32 = [10000, 15380.0, 5065.31, 877.468085106, 137.228070175, 36]


plt.plot([16]* len(Avg_16), Avg_16)
plt.plot([32]* len(Avg_32), Avg_32)
plt.yscale('log')

# %%
loop_1 = [13135.85, 6400, 10250, 11000, 11000, 10000]
loop_100 = [10001.4150943,5300.0, 13800.0, 15650.0, 14748.3870968, 15380.0]
loop_1000 = [5544.0952381, 1300, 6825.80645161, 2200.0, 4300, 5065.31531532]
loop_10000 = [1475.32, 950, 1112.19607843, 979.193548387, 700, 877.468085106]
loop_100000 = [173.2, 178.11, 135.9375, 180.631578947, 151.523809524, 137.228070175]
loop_500000 = [40.625, 36.8888888889, 33.857, 35.6, 38.4545454545, 36]

thr = [1,2,4,8,16,32]
plt.plot(thr, loop_1)
plt.plot(thr, loop_100)
plt.plot(thr, loop_1000)
plt.plot(thr, loop_10000)
plt.plot(thr, loop_100000)
plt.plot(thr, loop_500000)
