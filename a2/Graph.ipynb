# %%
import matplotlib.pyplot as plt
import numpy
# %matplotlib inline

# %%
loop_1 = [13135.85, 6400, 10250, 11000, 11000, 10000]
loop_100 = [10001.4150943,5300.0, 13800.0, 15650.0, 14748.3870968, 15380.0]
loop_1000 = [5544.0952381, 3300, 2825.80645161, 3200.0, 4300, 5065.31531532]
loop_10000 = [1475.32, 950, 1112.19607843, 979.193548387, 700, 877.468085106]
loop_100000 = [173.2, 178.11, 175.9375, 160.631578947, 151.523809524, 137.228070175]
loop_500000 = [30.625, 36.89, 36.857, 37.6, 38.4545454545, 36]

thr = [1,2,4,8,16,32]

plt.plot(thr, loop_1, label = "NUM OF LOOPS 1")
plt.plot(thr, loop_100, label = "NUM OF LOOPS 100")
plt.plot(thr, loop_1000, label = "NUM OF LOOPS 1000")
plt.plot(thr, loop_10000, label = "NUM OF LOOPS 10000")
plt.plot(thr, loop_100000, label = "NUM OF LOOPS 100000")
plt.plot(thr, loop_500000, label = "NUM OF LOOPS 500000")
plt.legend()
plt.yscale('log')
plt.savefig('foo.png')
